# %% [markdown]
# # Tarea 1 · Pandas
#
# **Alumno:** Roddy Huarhua
# **Curso:** Diplomado en Ciencia de Datos – PUCP
# **Fecha:** 20 de septiembre de 2026
#
# ## Tema del análisis
#
# **Análisis de datos del sector minero peruano**
#
# El objetivo de esta tarea es utilizar Pandas para cargar, explorar, limpiar y analizar una base de datos relacionada con el sector minero peruano. A partir de los datos se formularán preguntas sustantivas vinculadas con su distribución territorial y posteriormente se realizará un cruce con una segunda fuente de información.
#
# ## Fuente de datos
#
# La fuente principal será una base de datos pública oficial del sector minero peruano. Antes de realizar el análisis se verificará que contenga como mínimo 500 filas y 5 columnas, de acuerdo con los requisitos de la tarea.

# %%
import pandas as pd

# %% [markdown]
# **Explicación:**
# Importo la biblioteca Pandas y utilizo la abreviatura `pd`, que es la convención habitual en Python. Pandas me permitirá trabajar con los datos organizados en filas y columnas, cargar el archivo Excel y posteriormente limpiar, agrupar y analizar la información.

# %% [markdown]
# ## 1. Cargar y describir los datos
#
# En esta sección cargaré el Padrón Minero Nacional 2026 y realizaré una primera revisión de su estructura. Verificaré sus dimensiones, el significado de cada fila, los tipos de datos y la presencia de valores nulos.

# %%
import os

os.getcwd()
# Out:
# 'c:\\Users\\huarh\\OneDrive\\Documentos\\GitHub\\Diplomado_PUCP_Roddy\\assignments'

# %%
ruta_padron = "../data/tarea1_huarhua/PADRON_MINERO_2026.xlsx"

df = pd.read_excel(ruta_padron)

df.head()
# Out:
#    SEC  RUBRO       NOMBRE_DERECHO       CODIGO CODIGO_UEA_2025  \
# 0    1      1                  888    690002724             NaN
# 1    2      1  1949-07-01 00:00:00     50032918             NaN
# 2    3      1  1979-02-01 00:00:00  10009257X02      010003584U
# 3    4      1  1979-07-01 00:00:00  06006918X01             NaN
# 4    5      1  2001-03-01 00:00:00    710012822             NaN
#
#    HECTAREAS_2025 MONEDA_VIGENCIA_2025  VIGENCIA_2025 MONEDA_PENALIDAD_2025  \
# 0        100.0000                  DOL         300.00                   SOL
# 1         30.6602                  DOL           0.00                   SOL
# 2        998.7697                  DOL           0.00                   SOL
# 3        182.5051                  DOL         547.52                   SOL
# 4        500.0000                  DOL           0.00                   SOL
#
#    PENALIDAD_2025 CODIGO_UEA_2026  HECTAREAS_2026  \
# 0            0.00             NaN        100.0000
# ...
